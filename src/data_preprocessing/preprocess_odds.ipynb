# %%
import os
import pandas as pd

# %% [markdown]
# # Load the Data

# %%
# load the clean database tables
players_df = pd.read_csv('tennis_players_table.csv')
matches_df = pd.read_csv('tennis_matches_table.csv')
tournaments_df = pd.read_csv('tennis_tournaments_table.csv')

# load the messy odds table that must be linked to the database
odds_df = pd.concat([pd.read_csv('odds_atp.csv'), pd.read_csv('odds_wta.csv')]).drop(columns=['Unnamed: 0'])
# Out:
# /usr/local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (3,11) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /usr/local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (15,21,22,28,31,47,48,52) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /usr/local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (3,12,17) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# # Parse Odds Player Names

# %%
# this function pulls the first initial and last name from a name formatted like: Capp N.
# it applies a few extra steps to attempt to match better the data that is in the database
def parse_name(x):
    
    # db does not have the ' character
    x = x.lower().replace("'", "")
    
    # split the name on whitespace
    parts = x.split(' ')
    
    # simply grab the first initial from the end
    first_initial = parts[-1]
    
    # add back in the white space to the last name
    last_name = ' '.join(parts[:-1])
 
    # FIX: remove the first part of the hypenated last name
    if '-' in last_name:
        last_name = last_name.split('-')[-1]
    
    return first_initial, last_name

def parse_last_name(x):
    return parse_name(x)[1]
def parse_first_initial(x):
    initial = parse_name(x)[0]
    
    # FIX: for multiple initials just take the first one
    initial = initial.split('.')[0]

    return initial

# get all the unique names in the odds dataset
odds_names = list(set(odds_df['Winner'].unique())) + list(set(odds_df['Loser'].unique()))
names_df = pd.DataFrame({'name': odds_names}).drop_duplicates()

# parse out last name and first initial from the names in the odds dataset
names_df['last_name'] = names_df['name'].apply(parse_last_name)
names_df['first_initial'] = names_df['name'].apply(parse_first_initial)
names_df
# Out:
#                     name        last_name first_initial
# 0           Solovieva V.        solovieva             v
# 1             Troicki V.          troicki             v
# 2               Elias G.            elias             g
# 3            Voracova R.         voracova             r
# 4             Kralert P.          kralert             p
# ...                  ...              ...           ...
# 4135            Lopes H.            lopes             h
# 4138         Gigounon G.         gigounon             g
# 4141  Wachiramanowong K.  wachiramanowong             k
# 4143              Tan H.              tan             h
# 4151            Piros Z.            piros             z
#
# [2521 rows x 3 columns]

# %% [markdown]
# # Parse DB Player Names

# %%
# this function parses out the first initial from a name formatted like: Noah Capp
def parse_first_initial(x):
    x = x.lower()
    parts = x.split(' ')
    first_name = parts[0]


    if len(first_name) == 0:
        return ''
    else:
        return first_name[0]

# this function parses out the first initial from a name formatted like: Noah Capp
# NOTE: it treats names like Noah El Capp as {Noah},{Van Capp} etc.
# TODO: make more special cases!
def parse_last_name(x):
    x = x.lower()
    parts = x.split(' ')
    extras = ['el', 'van', 'di', 'herazo']
    if len(parts) > 1:
        last_name = parts[-1]
        for extra in extras:
            if extra in parts:
                last_name = extra+' '+last_name
        return last_name
    else:
        print(x)

# parse the last name and first initial from the names as well
players_df['first_initial'] = players_df['name'].apply(parse_first_initial)
players_df['last_name'] = players_df['name'].apply(parse_last_name)
players_df
# Out:
#           id                  name hand  height  ioc         dob league  \
# 0          0       Daniil Medvedev    R   198.0  RUS  1996-02-11    atp
# 1          1    Jo-Wilfried Tsonga    R   188.0  FRA  1985-04-17    atp
# 2          2         Jeremy Chardy    R   188.0  FRA  1987-02-12    atp
# 3          3        Alex De Minaur    R   183.0  AUS  1999-02-17    atp
# 4          4          Milos Raonic    R   196.0  CAN  1990-12-27    atp
# ...      ...                   ...  ...     ...  ...         ...    ...
# 41110  41110  Raminta Mackeviciute    U     NaN  LTU  1971-05-08    wta
# 41111  41111        Marlene Zuleta    U     NaN  CHI  1964-08-13    wta
# 41112  41112           Siri Mittet    U     NaN  NOR  1973-06-30    wta
# 41113  41113        Tina Vukasovic    U     NaN  SLO  1975-09-06    wta
# 41114  41114           Pirjo Ojala    U     NaN  FIN  1961-08-11    wta
#
#       first_initial     last_name
# 0                 d      medvedev
# 1                 j        tsonga
# 2                 j        chardy
# 3                 a        minaur
# 4                 m        raonic
# ...             ...           ...
# 41110             r  mackeviciute
# 41111             m        zuleta
# 41112             s        mittet
# 41113             t     vukasovic
# 41114             p         ojala
#
# [41115 rows x 9 columns]

# %% [markdown]
# # Replace Odds Names with Player ID

# %%
# merge the odds and players datasets using the parsed last names and first initials
# IMPORTANT NOTE: we have multiple players from the database per name in the odds dataset, this is because the only 
#                 identifier for the player in the odds dataset is their name, we must later figure out who it is
#                 based on the match information
name_merge = names_df.merge(
    players_df, 
    on=['last_name', 'first_initial'], 
    how='left', 
    suffixes=['_odds', '_players']
)
print('TODO: num missing players: %d/%d' % (len(name_merge[name_merge['id'].isna()]), len(name_merge)))
print('num players:', len(name_merge), 'num odds names:', len(names_df))

# replace the winner and loser names with the player id
tmp = odds_df.merge(name_merge[['name_odds', 'id']], left_on='Winner', right_on='name_odds', how='left')
tmp = tmp.merge(name_merge[['name_odds', 'id']], left_on='Loser', right_on='name_odds', suffixes=['_winner', '_loser'], how='left')
tmp = tmp.rename(columns={'id_winner': 'winner_id', 'id_loser': 'loser_id'})
tmp = tmp.drop_duplicates()

# NOTE: here is where we see that we now have more matches in the odds dataset after the join
#.       this again is because Noel Capp and Noah Capp will have the same name in the odds dataset for now
print('odds_matches:', len(odds_df), 'odds_matches with ambiguous player id:', len(tmp))
# Out:
# TODO: num missing players: 323/3275
# num players: 3275 num odds names: 2521
# odds_matches: 86961 odds_matches with ambiguous player id: 132514

# %%
odds_df = tmp[~(tmp['winner_id'].isna() | tmp['loser_id'].isna())]
odds_df
# Out:
#         ATP  AvgL  AvgW  B&WL  B&WW B365L  B365W  Best of  CBL  CBW  ...  \
# 0       1.0   NaN   NaN   NaN   NaN   NaN    NaN        3  NaN  NaN  ...
# 1       1.0   NaN   NaN   NaN   NaN   NaN    NaN        3  NaN  NaN  ...
# 2       1.0   NaN   NaN   NaN   NaN   NaN    NaN        3  NaN  NaN  ...
# 3       1.0   NaN   NaN   NaN   NaN   NaN    NaN        3  NaN  NaN  ...
# 4       1.0   NaN   NaN   NaN   NaN   NaN    NaN        3  NaN  NaN  ...
# ...     ...   ...   ...   ...   ...   ...    ...      ...  ...  ...  ...
# 132507  NaN  1.94  1.86   NaN   NaN   1.9   1.80        3  NaN  NaN  ...
# 132508  NaN  2.34  1.60   NaN   NaN  2.37   1.53        3  NaN  NaN  ...
# 132510  NaN  2.49  1.54   NaN   NaN  2.37   1.57        3  NaN  NaN  ...
# 132511  NaN  2.49  1.54   NaN   NaN  2.37   1.57        3  NaN  NaN  ...
# 132513  NaN  2.03  1.79   NaN   NaN   2.1   1.72        3  NaN  NaN  ...
#
#           WPts WRank        Winner  Wsets                Tier   WTA  \
# 0          NaN    63    Dosedel S.    2.0                 NaN   NaN
# 1          NaN     5    Enqvist T.    2.0                 NaN   NaN
# 2          NaN    40     Escude N.    2.0                 NaN   NaN
# 3          NaN    65    Federer R.    2.0                 NaN   NaN
# 4          NaN    81   Fromberg R.    2.0                 NaN   NaN
# ...        ...   ...           ...    ...                 ...   ...
# 132507  4120.0   7.0     Bencic B.    1.0  Tour Championships  58.0
# 132508  3995.0   8.0  Svitolina E.    2.0  Tour Championships  58.0
# 132510  3995.0   8.0  Svitolina E.    1.0  Tour Championships  58.0
# 132511  3995.0   8.0  Svitolina E.    1.0  Tour Championships  58.0
# 132513  6476.0   1.0      Barty A.    2.0  Tour Championships  58.0
#
#         name_odds_winner  winner_id  name_odds_loser  loser_id
# 0             Dosedel S.      693.0      Ljubicic I.     815.0
# 1             Enqvist T.    12694.0       Clement A.     665.0
# 2              Escude N.      875.0    Baccanello P.    1198.0
# 3             Federer R.      107.0   Knippschild J.     643.0
# 4            Fromberg R.      765.0    Woodbridge T.    1083.0
# ...                  ...        ...              ...       ...
# 132507         Bencic B.    36975.0       Bertens K.   36882.0
# 132508      Svitolina E.    36657.0         Kenin S.   37910.0
# 132510      Svitolina E.    36657.0        Bencic B.    2999.0
# 132511      Svitolina E.    36657.0        Bencic B.   36975.0
# 132513          Barty A.    36843.0     Svitolina E.   36657.0
#
# [122606 rows x 60 columns]

# %% [markdown]
# # Replace Odds Match Info with DB Match ID

# %%
# add an ID column based on the table index to be able to quickly find the original rows later on
matches_df['match_id'] = matches_df.index
odds_df['odds_id'] = odds_df.index

# clean up/rename some columns to make joins easier
matches_df['winner_rank'] = matches_df['winner_rank'].apply(lambda x: float(x) if not x is str else pd.NA)
matches_df['loser_rank'] = matches_df['loser_rank'].apply(lambda x: float(x) if not x is str else pd.NA)
odds_df['winner_rank'] = pd.to_numeric(odds_df['WRank'], errors='coerce')
odds_df['loser_rank'] = pd.to_numeric(odds_df['LRank'], errors='coerce')
matches_df
# Out:
# /var/folders/hg/4srtxv9j1q16t8k21lzwg8wh0000gn/T/ipykernel_15069/3586009303.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   odds_df['odds_id'] = odds_df.index
# /var/folders/hg/4srtxv9j1q16t8k21lzwg8wh0000gn/T/ipykernel_15069/3586009303.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   odds_df['winner_rank'] = pd.to_numeric(odds_df['WRank'], errors='coerce')
# /var/folders/hg/4srtxv9j1q16t8k21lzwg8wh0000gn/T/ipykernel_15069/3586009303.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   odds_df['loser_rank'] = pd.to_numeric(odds_df['LRank'], errors='coerce')
#               tourney_id  match_num  winner_id winner_seed winner_entry  \
# 0        2019-M020-World        300        111         2.0          NaN
# 1        2019-M020-World        299          0         4.0          NaN
# 2        2019-M020-World        298        111         2.0          NaN
# 3        2019-M020-World        297          1         NaN           PR
# 4        2019-M020-World        296          0         4.0          NaN
# ...                  ...        ...        ...         ...          ...
# 1054205        1978-W001          1      33657         NaN          NaN
# 1054206        1978-W001          2      33648         NaN          NaN
# 1054207        1978-W001          3      33656         NaN          NaN
# 1054208        1978-W001          4      33657         NaN          NaN
# 1054209        1978-W001          5      33563         NaN          NaN
#
#                 winner_name winner_hand  winner_ht winner_ioc  winner_age  \
# 0             Kei Nishikori           R      178.0        JPN        29.0
# 1           Daniil Medvedev           R      198.0        RUS        22.8
# 2             Kei Nishikori           R      178.0        JPN        29.0
# 3        Jo-Wilfried Tsonga           R      188.0        FRA        33.7
# 4           Daniil Medvedev           R      198.0        RUS        22.8
# ...                     ...         ...        ...        ...         ...
# 1054205         Chris Evert           R      168.0        USA        23.8
# 1054206      Michelle Tyler           U        NaN        GBR        20.3
# 1054207       Virginia Wade           R      170.0        GBR        33.3
# 1054208         Chris Evert           R      168.0        USA        23.8
# 1054209          Sue Barker           R      165.0        GBR        22.5
#
#          ...  l_1stWon l_2ndWon l_SvGms l_bpSaved l_bpFaced  winner_rank  \
# 0        ...      34.0     20.0    14.0      10.0      15.0          9.0
# 1        ...      36.0      7.0    10.0      10.0      13.0         16.0
# 2        ...      15.0      6.0     8.0       1.0       5.0          9.0
# 3        ...      38.0      9.0    11.0       4.0       6.0        239.0
# 4        ...      46.0     19.0    15.0       2.0       4.0         16.0
# ...      ...       ...      ...     ...       ...       ...          ...
# 1054205  ...       NaN      NaN     NaN       NaN       NaN          NaN
# 1054206  ...       NaN      NaN     NaN       NaN       NaN          NaN
# 1054207  ...       NaN      NaN     NaN       NaN       NaN          NaN
# 1054208  ...       NaN      NaN     NaN       NaN       NaN          NaN
# 1054209  ...       NaN      NaN     NaN       NaN       NaN          NaN
#
#         winner_rank_points  loser_rank loser_rank_points  match_id
# 0                   3590.0        16.0            1977.0         0
# 1                   1977.0       239.0             200.0         1
# 2                   3590.0        40.0            1050.0         2
# 3                    200.0        31.0            1298.0         3
# 4                   1977.0        18.0            1855.0         4
# ...                    ...         ...               ...       ...
# 1054205                NaN         NaN               NaN   1054205
# 1054206                NaN         NaN               NaN   1054206
# 1054207                NaN         NaN               NaN   1054207
# 1054208                NaN         NaN               NaN   1054208
# 1054209                NaN         NaN               NaN   1054209
#
# [1054210 rows x 45 columns]

# %% [markdown]
# # Find matches between player id, player rank
# This gets ~77k matches

# %%
# merge the tables
merge_cols = ['winner_id', 'loser_id', 'winner_rank', 'loser_rank']
merged_df = matches_df.merge(odds_df, on=merge_cols)

# get only the successful merges
temp_df = merged_df[~merged_df['odds_id'].isna()]

# get the unique groups
match_groups = temp_df.groupby(merge_cols)

# get only the groups with 1 match in it, the rest are ambiguous
n = match_groups['odds_id'].nunique().reset_index()
valid = n[n['odds_id'] == 1].drop(columns=['odds_id'])
successful_df = valid.merge(temp_df, how='left')
successful_df
# Out:
#        winner_id  loser_id  winner_rank  loser_rank               tourney_id  \
# 0              0         1         16.0       140.0          2019-0407-World
# 1              0         1         16.0       239.0          2019-M020-World
# 2              0         2         16.0        35.0          2019-0407-World
# 3              0         4         16.0        18.0          2019-M020-World
# 4              0         4         32.0        20.0          2018-0329-World
# ...          ...       ...          ...         ...                      ...
# 75606      38463     36947        279.0        65.0  2009-W-INT-MAR-01A-2009
# 75607      38469     37188        271.0       357.0   2008-W-T2-IND-01A-2008
# 75608      38602     36821        306.0       454.0   2008-W-T3-TUR-01A-2008
# 75609      38702     36866        121.0        51.0                2019-M014
# 75610      38702     38026        211.0        92.0                2019-M035
#
#        match_num winner_seed winner_entry            winner_name winner_hand  \
# 0            294         5.0          NaN        Daniil Medvedev           R
# 1            299         4.0          NaN        Daniil Medvedev           R
# 2            273         5.0          NaN        Daniil Medvedev           R
# 3            296         4.0          NaN        Daniil Medvedev           R
# 4            296         NaN            Q        Daniil Medvedev           R
# ...          ...         ...          ...                    ...         ...
# 75606         11         NaN           LL  Eva Fernandez Brugues           R
# 75607         11         NaN            Q         Agnes Szatmari           R
# 75608          9         NaN            Q     Veronika Chvojkova           R
# 75609        283         NaN            Q       Varvara Gracheva           R
# 75610        280         NaN            Q       Varvara Gracheva           R
#
#        ...                Winner Wsets           Tier   WTA  \
# 0      ...           Medvedev D.   2.0            NaN   NaN
# 1      ...           Medvedev D.   2.0            NaN   NaN
# 2      ...           Medvedev D.   2.0            NaN   NaN
# 3      ...           Medvedev D.   2.0            NaN   NaN
# 4      ...           Medvedev D.   2.0            NaN   NaN
# ...    ...                   ...   ...            ...   ...
# 75606  ...  Fernandez-Brugues E.   2.0  International  19.0
# 75607  ...           Szatmari A.   2.0         Tier 2  15.0
# 75608  ...          Chvojkova V.   2.0         Tier 3  25.0
# 75609  ...           Gracheva V.   2.0        Premier  56.0
# 75610  ...           Gracheva V.   2.0  International  39.0
#
#            name_odds_winner name_odds_loser odds_id  winner_rank_points_y  \
# 0               Medvedev D.     Tsonga J.W.   86299                2160.0
# 1               Medvedev D.     Tsonga J.W.   85759                1977.0
# 2               Medvedev D.       Chardy J.   86287                2160.0
# 3               Medvedev D.       Raonic M.   85756                1977.0
# 4               Medvedev D.       Raonic M.   85356                1287.0
# ...                     ...             ...     ...                   ...
# 75606  Fernandez-Brugues E.    Cetkovska P.   96874                 176.0
# 75607           Szatmari A.      Lakhani I.   93194                  94.0
# 75608          Chvojkova V.        Ozgen P.   93915                  76.0
# 75609           Gracheva V.  Tomljanovic A.  132456                 541.0
# 75610           Gracheva V.     Blinkova A.  131530                 278.0
#
#       loser_rank_points_y  best_of_y
# 0                   405.0          3
# 1                   200.0          3
# 2                  1180.0          3
# 3                  1855.0          3
# 4                  1755.0          3
# ...                   ...        ...
# 75606               907.0          3
# 75607                60.0          3
# 75608                41.0          3
# 75609              1115.0          3
# 75610               664.0          3
#
# [75611 rows x 107 columns]

# %% [markdown]
# # Clean up the table to write out

# %%
out_df = successful_df.drop(columns=[
    'winner_rank', 'loser_rank', 
    'winner_seed', 'loser_seed', 
    'winner_entry', 'loser_entry',
    'winner_name', 'loser_name',
    'winner_hand', 'loser_hand',
    'winner_ht', 'loser_ht',
    'winner_ioc', 'loser_ioc',
    'winner_age', 'loser_age',
    'score', 'best_of_x', 'round', 'minutes', 
    'w_ace', 'l_ace',
    'w_df', 'l_df',
    'w_svpt', 'l_svpt',
    'w_1stIn', 'l_1stIn',
    'w_1stWon', 'l_1stWon',
    'w_2ndWon', 'l_2ndWon',
    'w_SvGms', 'l_SvGms',
    'w_bpSaved', 'l_bpSaved',
    'w_bpFaced', 'l_bpFaced',
    'winner_rank_points_x', 'loser_rank_points_x',
    'match_id', 'odds_id', 
    'ATP', 'Best of', 'Comment',
    'Court', 'Date',
    'Location', 'Loser', 'Winner',
    'Wsets', 'Lsets',
    'L1', 'L2', 'L3', 'L4', 'L5',
    'W1', 'W2', 'W3', 'W4', 'W5',
    'WPts', 'LPts',
    'WRank', 'LRank',
    'Round', 'Series',
    'Surface', 'Tournament',
    'Tier', 'WTA',
    'name_odds_winner', 'name_odds_loser',
    'winner_rank_points_y', 'loser_rank_points_y', 'best_of_y',
    'winner_id', 'loser_id',
])
out_df.to_csv('preprocessed_odds.csv')
out_df
# Out:
#                     tourney_id  match_num  AvgL  AvgW  B&WL  B&WW B365L  \
# 0              2019-0407-World        294  2.33  1.61   NaN   NaN  2.37
# 1              2019-M020-World        299  2.23  1.67   NaN   NaN   2.3
# 2              2019-0407-World        273  3.96  1.25   NaN   NaN   4.0
# 3              2019-M020-World        296  1.79  2.04   NaN   NaN   1.8
# 4              2018-0329-World        296  1.46  2.73   NaN   NaN  1.44
# ...                        ...        ...   ...   ...   ...   ...   ...
# 75606  2009-W-INT-MAR-01A-2009         11   NaN   NaN   NaN   NaN  1.11
# 75607   2008-W-T2-IND-01A-2008         11   NaN   NaN   NaN   NaN  2.75
# 75608   2008-W-T3-TUR-01A-2008          9   NaN   NaN   NaN   NaN   2.5
# 75609                2019-M014        283  1.81  1.99   NaN   NaN  1.72
# 75610                2019-M035        280  1.49  2.60   NaN   NaN  1.44
#
#        B365W  CBL  CBW  ...  MaxL  MaxW   PSL    PSW  SBL  SBW  SJL SJW   UBL  \
# 0       1.57  NaN  NaN  ...  2.42  1.74  2.31  1.700  NaN  NaN  NaN NaN   NaN
# 1       1.61  NaN  NaN  ...  2.46  1.79  2.30  1.710  NaN  NaN  NaN NaN   NaN
# 2       1.22  NaN  NaN  ...  4.40  1.30  4.06  1.280  NaN  NaN  NaN NaN   NaN
# 3       2.00  NaN  NaN  ...  1.91  2.16  1.80  2.160  NaN  NaN  NaN NaN   NaN
# 4       2.75  NaN  NaN  ...  1.53  2.87  1.49  2.870  NaN  NaN  NaN NaN   NaN
# ...      ...  ...  ...  ...   ...   ...   ...    ...  ...  ...  ...  ..   ...
# 75606   6.00  NaN  NaN  ...   NaN   NaN   NaN    NaN  NaN  NaN  NaN NaN  1.12
# 75607   1.40  NaN  NaN  ...   NaN   NaN  3.00  1.455  NaN  NaN  NaN NaN   NaN
# 75608   1.50  NaN  NaN  ...   NaN   NaN   NaN    NaN  NaN  NaN  NaN NaN   NaN
# 75609   2.00  NaN  NaN  ...  1.89  2.10  1.81  2.090  NaN  NaN  NaN NaN   NaN
# 75610   2.62  NaN  NaN  ...  1.53  2.78  1.51  2.720  NaN  NaN  NaN NaN   NaN
#
#        UBW
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ...    ...
# 75606  6.0
# 75607  NaN
# 75608  NaN
# 75609  NaN
# 75610  NaN
#
# [75611 rows x 28 columns]
